# %%
import pandas as pd

# %%
stats = pd.read_csv("stats.csv")

# %%
stats
# Out:
#        Unnamed: 0          Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0               0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  ...
# 1               1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  ...
# 2               2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  ...
# 3               3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  ...
# 4               4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  ...
# ...           ...             ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 14087       14087   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  ...
# 14088       14088     Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  ...
# 14089       14089  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  ...
# 14090       14090      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  ...
# 14091       14091      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  ...
#
# ...

# %%
stats.dtypes
# Out:
# Unnamed: 0        int64
# Player           object
# Pos              object
# Age               int64
# Tm               object
#                   ...
# TOTAL_PF          int64
# TOTAL_PTS         int64
# min_age           int64
# TOTAL_seasons     int64
# season_index      int64
# Length: 102, dtype: object

# %%
pd.isnull(stats).sum()
# Out:
# Unnamed: 0       0
# Player           0
# Pos              0
# Age              0
# Tm               0
#                 ..
# TOTAL_PF         0
# TOTAL_PTS        0
# min_age          0
# TOTAL_seasons    0
# season_index     0
# Length: 102, dtype: int64

# %%
pd.isnull(stats).sum().head(50)
# Out:
# Unnamed: 0        0
# Player            0
# Pos               0
# Age               0
# Tm                0
# G                 0
# GS                0
# MP                0
# FG                0
# FGA               0
# FG%              50
# 3P                0
# 3PA               0
# 3P%            2042
# 2P                0
# 2PA               0
# 2P%              84
# eFG%             50
# FT                0
# FTA               0
# FT%             462
# ORB               0
# DRB               0
# TRB               0
# AST               0
# STL               0
# BLK               0
# TOV               0
# PF                0
# PTS               0
# Year              0
# Pts Won           0
# Pts Max           0
# Share             0
# Team              0
# W                 0
# L                 0
# W/L%              0
# GB                0
# PS/G              0
# PA/G              0
# SRS               0
# FG_per_100        3
# FGA_per_100       3
# 3P_per_100        3
# ...

# %%
stats[pd.isnull(stats["ORtg"])][["Player", "FGA","MP","Year"]].head()
# Out:
#                    Player  FGA   MP  Year
# 103       Adrian Caldwell  0.0  3.0  1998
# 428            Gani Lawal  0.0  2.0  2011
# 2776  Trey McKinney-Jones  0.0  1.0  2018
# 3172           Andy Panko  0.0  1.0  2001
# 3894          Alex Scales  0.0  0.0  2006

# %%
pd.isnull(stats).sum().tail(31)
# Out:
# TOV%             36
# USG%              3
# OWS               0
# DWS               0
# WS                0
# WS/48             3
# OBPM              0
# DBPM              0
# BPM               0
# VORP              0
# TOTAL_MP          0
# TOTAL_FG          0
# TOTAL_FGA         0
# TOTAL_3P          0
# TOTAL_3PA         0
# TOTAL_2P          0
# TOTAL_2PA         0
# TOTAL_FT          0
# TOTAL_FTA         0
# TOTAL_ORB         0
# TOTAL_DRB         0
# TOTAL_TRB         0
# TOTAL_AST         0
# TOTAL_STL         0
# TOTAL_BLK         0
# TOTAL_TOV         0
# TOTAL_PF          0
# TOTAL_PTS         0
# min_age           0
# TOTAL_seasons     0
# season_index      0
# dtype: int64

# %%
stats = stats.fillna(0)

# %%
pd.isnull(stats).sum().tail(31)
# Out:
# TOV%             0
# USG%             0
# OWS              0
# DWS              0
# WS               0
# WS/48            0
# OBPM             0
# DBPM             0
# BPM              0
# VORP             0
# TOTAL_MP         0
# TOTAL_FG         0
# TOTAL_FGA        0
# TOTAL_3P         0
# TOTAL_3PA        0
# TOTAL_2P         0
# TOTAL_2PA        0
# TOTAL_FT         0
# TOTAL_FTA        0
# TOTAL_ORB        0
# TOTAL_DRB        0
# TOTAL_TRB        0
# TOTAL_AST        0
# TOTAL_STL        0
# TOTAL_BLK        0
# TOTAL_TOV        0
# TOTAL_PF         0
# TOTAL_PTS        0
# min_age          0
# TOTAL_seasons    0
# season_index     0
# dtype: int64

# %%
stats.groupby(["Player"]).get_group(("Greg Anderson"))
# Out:
#       Unnamed: 0         Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 3139        3139  Greg Anderson   C   33  ATL  50   0   8.0  0.7   1.6  ...
# 4194        4194  Greg Anderson  PF   29  DET  77  47  21.1  2.6   4.8  ...
# 7053        7053  Greg Anderson  PF   30  ATL  51   0  12.2  1.1   2.0  ...
# 7856        7856  Greg Anderson  PF   26  DEN  68   2  13.6  1.7   4.0  ...
# 7871        7871  Greg Anderson  PF   27  DEN  82  82  34.1  4.7  10.4  ...
# 9833        9833  Greg Anderson  PF   31  SAS  46   7   7.5  0.5   1.0  ...
# 9846        9846  Greg Anderson   C   32  SAS  82  48  20.2  1.6   3.2  ...
#
#       TOTAL_TRB  TOTAL_AST  TOTAL_STL  TOTAL_BLK  TOTAL_TOV  TOTAL_PF  \
# 3139        118         15         19         10         17        85
# 4194        571         51         55         68         94       234
# 7053        188         17         23         32         32       103
# 7856        318         16         35         45         84       140
# ...

# %%
stats.dropna(subset=['TOTAL_MP'], inplace = True)
stats = stats[stats['TOTAL_MP'] >= 400]

# %%
stats
# Out:
#        Unnamed: 0          Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0               0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  ...
# 1               1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  ...
# 4               4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  ...
# 5               5      Larry Drew  PG   32  LAL  48   2  10.3  1.1   2.6  ...
# 6               6   Magic Johnson  PG   31  LAL  79  79  37.1  5.9  12.4  ...
# ...           ...             ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 14086       14086   Rashad Vaughn  SG   20  MIL  41   2  11.2  1.4   3.8  ...
# 14087       14087   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  ...
# 14089       14089  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  ...
# 14090       14090      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  ...
# 14091       14091      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  ...
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_seasons'
#
# The above exception was the direct cause of the following exception:
#
# ...
